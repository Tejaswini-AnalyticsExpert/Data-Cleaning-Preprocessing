# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejaswini-AnalyticsExpert/Data-Cleaning-Preprocessing/blob/main/Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Load Raw Data **bold text**

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Define the file paths (update folder name if needed)
file1 = 'Fitness Classes Data/Classes April-May 2018.csv'
file2 = 'Fitness Classes Data/Classes June 2018.csv'

# Read the collected data into pandas DataFrames
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)

# Combine the two datasets into one
df = pd.concat([df1, df2], ignore_index=True)

print(f"Data loaded. Total rows: {len(df)}")
df.head()
# Out:
# Data loaded. Total rows: 3289
#   ActivitySiteID      ActivityDescription  \
# 0            HXP  20-20-20  2.45pm-3.45pm
# 1            HXP  20-20-20  2.45pm-3.45pm
# 2            HXP  20-20-20  2.45pm-3.45pm
# 3            HXP  20-20-20  2.45pm-3.45pm
# 4            HXP  20-20-20  2.45pm-3.45pm
#
#   BookingEndDateTime (Month / Day / Year) BookingStartTime  MaxBookees  \
# 0                               08-Apr-18         14:45:00          25
# 1                               15-Apr-18         14:45:00          25
# 2                               22-Apr-18         14:45:00          25
# 3                               29-Apr-18         14:45:00          25
# 4                               06-May-18         14:45:00          25
#
#    Number Booked  Price (INR)
# 0             12        499.0
# 1             15        499.0
# 2             14        499.0
# 3              9        499.0
# 4              7        499.0

# %% [markdown]
# 2. Clean **Data**

# %%
# 1. Remove duplicates
initial_count = len(df)
df = df.drop_duplicates()
print(f"Removed {initial_count - len(df)} duplicate rows.")

# 2. Handle missing values
# Checking for nulls
print("Missing values before cleaning:\n", df.isnull().sum())

# We will fill missing Price values with the median price
# (or use df.dropna() if you're not allowed to guess values)
df['Price (INR)'] = df['Price (INR)'].fillna(df['Price (INR)'].median())

# 3. Correct data types
# Ensure Price is a float for calculations
df['Price (INR)'] = df['Price (INR)'].astype(float)

print("\nData cleaning step finished.")
# Out:
# Removed 0 duplicate rows.
# Missing values before cleaning:
#  ActivitySiteID                              0
# ActivityDescription                         0
# BookingEndDateTime (Month / Day / Year)     0
# BookingStartTime                            0
# MaxBookees                                  0
# Number Booked                               0
# Price (INR)                                18
# dtype: int64
#
# Data cleaning step finished.

# %% [markdown]
# 3. Transform **Data**

# %%
# 1. Standardize date formats

date_col = 'BookingEndDateTime (Month / Day / Year)'
df[date_col] = pd.to_datetime(df[date_col], dayfirst=False)

# 2. Normalize or scale numerical features
# We will scale 'MaxBookees' and 'Number Booked' using StandardScaler
scaler = StandardScaler()
cols_to_scale = ['MaxBookees', 'Number Booked']

# Creating a new column for scaled data so we don't lose the original numbers
df[['MaxBookees_Scaled', 'Number Booked_Scaled']] = scaler.fit_transform(df[cols_to_scale])

print("Data transformation complete!")
df.head()
# Out:
# Data transformation complete!
# /tmp/ipykernel_11722/2723687587.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[date_col] = pd.to_datetime(df[date_col], dayfirst=False)
#   ActivitySiteID      ActivityDescription  \
# 0            HXP  20-20-20  2.45pm-3.45pm
# 1            HXP  20-20-20  2.45pm-3.45pm
# 2            HXP  20-20-20  2.45pm-3.45pm
# 3            HXP  20-20-20  2.45pm-3.45pm
# 4            HXP  20-20-20  2.45pm-3.45pm
#
#   BookingEndDateTime (Month / Day / Year) BookingStartTime  MaxBookees  \
# 0                              2018-04-08         14:45:00          25
# 1                              2018-04-15         14:45:00          25
# 2                              2018-04-22         14:45:00          25
# 3                              2018-04-29         14:45:00          25
# 4                              2018-05-06         14:45:00          25
#
#    Number Booked  Price (INR)  MaxBookees_Scaled  Number Booked_Scaled
# 0             12        499.0          -0.475775             -0.535512
# 1             15        499.0          -0.475775             -0.219810
# 2             14        499.0          -0.475775             -0.325044
# 3              9        499.0          -0.475775             -0.851213
# 4              7        499.0          -0.475775             -1.061680
